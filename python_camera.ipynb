# %%
# %pip install mediapipe opencv-python

# %%
import socket
import cv2
import mediapipe as mp
import math
import time

# %%
def count_extended_fingers(lm_list):
    # Tip IDs: thumb=4, index=8, middle=12, ring=16, pinky=20
    tip_ids = [4, 8, 12, 16, 20]
    extended = 0
    # Thumb: compare x of tip vs IP for handedness
    if lm_list[tip_ids[0]][1] < lm_list[tip_ids[0] - 1][1]:
        extended += 1
    # Other fingers: tip y < PIP y => extended
    for i in range(1, 5):
        if lm_list[tip_ids[i]][2] < lm_list[tip_ids[i] - 2][2]:
            extended += 1
    return extended

# %%
verbose = True  # Set to False to disable drawing
esp_ip = "192.168.229.171"  # Replace with the IP shown in Serial Monitor
# esp_ip = "172.20.10.3"  # Replace with the IP shown in Serial Monitor
esp_port = 8888             # Must match `WiFiServer server(8888)`


with socket.socket(socket.AF_INET, socket.SOCK_DGRAM) as s:
    # s.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
    s.settimeout(10)  # Optional: timeout for safety
    s.connect((esp_ip, esp_port))
    print("Connected to ESP8266 at", esp_ip)
    # Send message
    msg = "Connected to ESP8266\n"
    s.sendall(msg.encode())

    time.sleep(0.1)
    # Read echo and confirmation
    # response1 = s.recv(1024).decode().strip()
    # print(f"Echoed: {response1}")

    mp_hands = mp.solutions.hands
    mp_drawing = mp.solutions.drawing_utils
    hands = mp_hands.Hands(
        static_image_mode=False,
        max_num_hands=1,
        min_detection_confidence=0.7,
        min_tracking_confidence=0.7
    )
    prev_is_open = 0
    prev_theta = 0
    prev_time = time.time()

    cap = cv2.VideoCapture(0)
    if not cap.isOpened():
        print("Cannot open webcam")

    try:
        while True:
            ret, frame = cap.read()
            if not ret:
                break

            # Mirror and get dimensions
            frame = cv2.flip(frame, 1)
            h, w, _ = frame.shape
            # Compute center after flip
            center_frame = (w // 2, h // 2)


            # Draw center dot correctly at center_frame
            cv2.circle(frame, center_frame, 5, (255, 255, 255), -1)

            # Process with MediaPipe
            rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

            results = hands.process(rgb)
            if results.multi_hand_landmarks:
                hand_landmarks = results.multi_hand_landmarks[0]
                # Landmark list in pixel coords
                lm_list = [[id, int(lm.x * w), int(lm.y * h)]
                            for id, lm in enumerate(hand_landmarks.landmark)]

                # Compute bounding box and hand center
                xs = [pt[1] for pt in lm_list]
                ys = [pt[2] for pt in lm_list]
                xmin, xmax = min(xs), max(xs)
                ymin, ymax = min(ys), max(ys)
                hand_center = ((xmin + xmax) // 2, (ymin + ymax) // 2)

                # Determine open vs fist
                cnt = count_extended_fingers(lm_list)
                is_open = cnt >= 2

                # Compute angle θ from North clockwise
                dx = hand_center[0] - center_frame[0]
                dy = center_frame[1] - hand_center[1]
                theta = math.degrees(math.atan2(dx, dy))
                # theta = theta if theta >= 0 else theta + 360

                # Send data to ESP8266
                if is_open != prev_is_open or abs(theta - prev_theta) > 5:
                    prev_is_open = is_open
                    prev_theta = theta
                    # Send data to ESP8266

                    now = time.time()
                    if (s is not None) and (now - prev_time > 0.1):
                        message = f"{int(is_open)},{int(theta)}\n"
                        s.sendall(message.encode())
                        # time.sleep(0.1)
                        prev_time = now


                # Visual Feedback
                if verbose:
                    # Draw bounding box
                    if is_open:
                        box_color = (0, 255, 0)
                        label = f'Open ({cnt})'
                    else:
                        box_color = (0, 0, 255)
                        label = f'Fist ({cnt})'

                    cv2.rectangle(frame,
                                (xmin - 10, ymin - 10),
                                (xmax + 10, ymax + 10),
                                box_color, 2)
                    cv2.putText(frame, label,
                                (xmin, ymin - 25),
                                cv2.FONT_HERSHEY_SIMPLEX, 0.8,
                                box_color, 2)

                    # Draw center dot and angle line
                    cv2.circle(frame, center_frame, 5, (255, 255, 255), -1)
                    cv2.line(frame, center_frame, hand_center, box_color, 2)

                    # Display angle text
                    angle_text = f'Theta: {int(theta):3d}°'
                    cv2.putText(frame, angle_text,
                                (10, 30),
                                cv2.FONT_HERSHEY_SIMPLEX, 0.8,
                                (255, 255, 255), 2)

                    # Draw landmarks AFTER everything else
                    mp_drawing.draw_landmarks(
                        frame, hand_landmarks, mp_hands.HAND_CONNECTIONS)


                    print(f"Is Open: {is_open}, Angle: {theta:.2f} degrees")

            else:
                now = time.time()
                if (s is not None) and (now - prev_time > 0.1):
                    message = f"{0},{0}\n"
                    s.sendall(message.encode())
                    # time.sleep(0.1)
                    prev_time = now
            cv2.imshow("Hand Tracking & Angle", frame)
            if cv2.waitKey(1) & 0xFF == 27:
                break

    except KeyboardInterrupt:
        print("Interrupted by user")
    finally:
        cap.release()
        cv2.destroyAllWindows()

        message = f"{0},{0}\n"
        s.sendall(message.encode())
# Out:
# Connected to ESP8266 at 192.168.229.171
# Is Open: True, Angle: 146.02 degrees
# Is Open: True, Angle: 144.64 degrees
# Is Open: True, Angle: 147.33 degrees
# Is Open: True, Angle: 142.51 degrees
# Is Open: True, Angle: 138.01 degrees
# Is Open: True, Angle: 130.67 degrees
# Is Open: True, Angle: 120.10 degrees
# Is Open: True, Angle: 109.44 degrees
# Is Open: True, Angle: 98.37 degrees
# Is Open: True, Angle: 90.81 degrees
# Is Open: True, Angle: 86.24 degrees
# Is Open: True, Angle: 84.03 degrees
# Is Open: True, Angle: 84.17 degrees
# Is Open: True, Angle: 84.90 degrees
# Is Open: True, Angle: 84.69 degrees
# Is Open: True, Angle: 85.24 degrees
# Is Open: True, Angle: 85.21 degrees
# Is Open: True, Angle: 84.32 degrees
# Is Open: True, Angle: 83.55 degrees
# Is Open: True, Angle: 81.63 degrees
# Is Open: True, Angle: 79.67 degrees
# Is Open: True, Angle: 77.25 degrees
# Is Open: True, Angle: 75.09 degrees
# Is Open: True, Angle: 72.80 degrees
# Is Open: True, Angle: 69.82 degrees
# Is Open: True, Angle: 66.72 degrees
# Is Open: True, Angle: 63.43 degrees
# Is Open: True, Angle: 61.06 degrees
# Is Open: True, Angle: 58.60 degrees
# Is Open: True, Angle: 56.61 degrees
# Is Open: True, Angle: 55.57 degrees
# Is Open: True, Angle: 54.13 degrees
# Is Open: True, Angle: 51.67 degrees
# Is Open: True, Angle: 48.01 degrees
# Is Open: True, Angle: 43.38 degrees
# Is Open: True, Angle: 37.53 degrees
# Is Open: True, Angle: 30.11 degrees
# Is Open: True, Angle: 16.94 degrees
# Is Open: True, Angle: 4.73 degrees
# Is Open: True, Angle: -6.73 degrees
# Is Open: True, Angle: -18.81 degrees
# Is Open: True, Angle: -28.58 degrees
# Is Open: True, Angle: -35.77 degrees
# Is Open: True, Angle: -40.60 degrees
# Is Open: True, Angle: -44.45 degrees
# Is Open: True, Angle: -46.37 degrees
# Is Open: True, Angle: -48.24 degrees
# Is Open: True, Angle: -48.21 degrees
# Is Open: True, Angle: -48.95 degrees
# Is Open: True, Angle: -48.46 degrees
# Is Open: True, Angle: -47.90 degrees
# Is Open: True, Angle: -47.08 degrees
# Is Open: True, Angle: -46.80 degrees
# Is Open: True, Angle: -44.22 degrees
# Is Open: True, Angle: -39.90 degrees
# Is Open: True, Angle: -36.00 degrees
# Is Open: True, Angle: -30.53 degrees
# Is Open: True, Angle: -21.72 degrees
# Is Open: True, Angle: -9.04 degrees
# Is Open: True, Angle: 3.15 degrees
# Is Open: True, Angle: 15.45 degrees
# Is Open: True, Angle: 27.85 degrees
# Is Open: True, Angle: 38.05 degrees
# Is Open: True, Angle: 45.76 degrees
# Is Open: True, Angle: 50.28 degrees
# Is Open: True, Angle: 52.80 degrees
# Is Open: True, Angle: 54.50 degrees
# Is Open: True, Angle: 55.41 degrees
# Is Open: True, Angle: 55.41 degrees
# Is Open: True, Angle: 55.68 degrees
# Is Open: True, Angle: 55.68 degrees
# Is Open: True, Angle: 55.59 degrees
# Is Open: True, Angle: 56.04 degrees
# Is Open: True, Angle: 56.49 degrees
# Is Open: True, Angle: 56.94 degrees
# Is Open: True, Angle: 57.21 degrees
# Is Open: True, Angle: 57.65 degrees
# Is Open: True, Angle: 57.82 degrees
# Is Open: True, Angle: 57.99 degrees
# Is Open: True, Angle: 58.71 degrees
# Is Open: True, Angle: 59.31 degrees
# Is Open: True, Angle: 59.79 degrees
# Is Open: True, Angle: 61.07 degrees
# Is Open: True, Angle: 61.64 degrees
# Is Open: True, Angle: 62.34 degrees
# Is Open: True, Angle: 62.89 degrees
# Is Open: True, Angle: 62.90 degrees
# Is Open: True, Angle: 63.03 degrees
# Is Open: True, Angle: 63.43 degrees
# Is Open: True, Angle: 63.30 degrees
# Is Open: True, Angle: 62.76 degrees
# Is Open: True, Angle: 62.61 degrees
# Is Open: True, Angle: 62.47 degrees
# Is Open: True, Angle: 62.18 degrees
# Is Open: True, Angle: 61.61 degrees
# Is Open: True, Angle: 61.46 degrees
# Is Open: True, Angle: 61.59 degrees
# Is Open: True, Angle: 61.44 degrees
# Is Open: True, Angle: 61.42 degrees
# Is Open: True, Angle: 60.82 degrees
# Is Open: True, Angle: 60.66 degrees
# Is Open: True, Angle: 60.17 degrees
# Is Open: True, Angle: 59.33 degrees
# Is Open: True, Angle: 57.48 degrees
# Is Open: True, Angle: 53.20 degrees
# Is Open: True, Angle: 46.21 degrees
# Is Open: True, Angle: 34.99 degrees
# Is Open: True, Angle: 16.53 degrees
# Is Open: True, Angle: -6.41 degrees
# Is Open: True, Angle: -29.05 degrees
# Is Open: True, Angle: -49.09 degrees
# Is Open: True, Angle: -65.39 degrees
# Is Open: True, Angle: -73.01 degrees
# Is Open: True, Angle: -79.82 degrees
# Is Open: True, Angle: -83.13 degrees
# Is Open: True, Angle: -86.35 degrees
# Is Open: True, Angle: -88.66 degrees
# Is Open: True, Angle: -90.52 degrees
# Is Open: True, Angle: -91.77 degrees
# Is Open: True, Angle: -92.28 degrees
# Is Open: True, Angle: -92.79 degrees
# Is Open: True, Angle: -92.77 degrees
# Is Open: True, Angle: -92.52 degrees
# Is Open: True, Angle: -92.75 degrees
# Is Open: True, Angle: -92.73 degrees
# Is Open: True, Angle: -92.69 degrees
# Is Open: True, Angle: -92.91 degrees
# Is Open: True, Angle: -93.14 degrees
# Is Open: True, Angle: -93.59 degrees
# Is Open: True, Angle: -93.83 degrees
# Is Open: True, Angle: -93.83 degrees
# Is Open: True, Angle: -93.81 degrees
# Is Open: True, Angle: -93.56 degrees
# Is Open: True, Angle: -93.56 degrees
# Is Open: True, Angle: -93.78 degrees
# Is Open: True, Angle: -93.56 degrees
# Is Open: True, Angle: -93.77 degrees
# Is Open: True, Angle: -93.75 degrees
# Is Open: True, Angle: -93.77 degrees
# Is Open: True, Angle: -94.00 degrees
# Is Open: True, Angle: -94.24 degrees
# Is Open: True, Angle: -94.24 degrees
# Is Open: True, Angle: -94.51 degrees
# Is Open: True, Angle: -94.76 degrees
# Is Open: True, Angle: -94.80 degrees
# Is Open: True, Angle: -95.06 degrees
# Is Open: True, Angle: -95.35 degrees
# Is Open: True, Angle: -95.61 degrees
# Is Open: True, Angle: -95.37 degrees
# Is Open: True, Angle: -93.95 degrees
# Is Open: True, Angle: -93.26 degrees
# Is Open: True, Angle: -91.50 degrees
# Is Open: True, Angle: -90.00 degrees
# Is Open: True, Angle: -88.15 degrees
# Is Open: True, Angle: -85.76 degrees
# Is Open: True, Angle: -83.89 degrees
# Is Open: True, Angle: -81.83 degrees
# Is Open: True, Angle: -79.60 degrees
# Is Open: True, Angle: -76.51 degrees
# Is Open: True, Angle: -74.19 degrees
# Is Open: True, Angle: -72.09 degrees
# Is Open: True, Angle: -69.96 degrees
# Is Open: True, Angle: -68.87 degrees
# Is Open: True, Angle: -68.08 degrees
# Is Open: True, Angle: -67.79 degrees
# Is Open: True, Angle: -68.32 degrees
# Is Open: True, Angle: -68.45 degrees
# Is Open: True, Angle: -69.34 degrees
# Is Open: True, Angle: -70.18 degrees
# Is Open: True, Angle: -70.97 degrees
# Is Open: True, Angle: -71.41 degrees
# Is Open: True, Angle: -71.80 degrees
# Is Open: True, Angle: -72.36 degrees
# Is Open: True, Angle: -73.13 degrees
# Is Open: True, Angle: -73.94 degrees
# Is Open: True, Angle: -74.02 degrees
# Is Open: True, Angle: -73.38 degrees
# Is Open: True, Angle: -72.32 degrees
# Is Open: True, Angle: -70.13 degrees
# Is Open: True, Angle: -68.01 degrees
# Is Open: True, Angle: -65.07 degrees
# Is Open: True, Angle: -60.68 degrees
# Is Open: True, Angle: -54.46 degrees
# Is Open: True, Angle: -47.49 degrees
# Is Open: True, Angle: -40.98 degrees
# Is Open: True, Angle: -30.89 degrees
# Is Open: True, Angle: -23.75 degrees
# Is Open: True, Angle: -19.57 degrees
# Is Open: True, Angle: -16.00 degrees
# Is Open: True, Angle: -13.48 degrees
# Is Open: True, Angle: -12.65 degrees
# Is Open: True, Angle: -12.07 degrees
# Is Open: True, Angle: -12.45 degrees
# Is Open: True, Angle: -12.53 degrees
# Is Open: True, Angle: -12.91 degrees
# Is Open: True, Angle: -13.11 degrees
# Is Open: True, Angle: -13.95 degrees
# Is Open: True, Angle: -14.57 degrees
# Is Open: True, Angle: -17.05 degrees
# Is Open: True, Angle: -19.24 degrees
# Is Open: True, Angle: -20.77 degrees
# Is Open: True, Angle: -21.60 degrees
# Is Open: True, Angle: -21.60 degrees
# Is Open: True, Angle: -21.52 degrees
# Is Open: True, Angle: -20.38 degrees
# Is Open: True, Angle: -19.29 degrees
# Is Open: True, Angle: -18.68 degrees
# Is Open: True, Angle: -18.43 degrees
# Is Open: True, Angle: -18.94 degrees
# Is Open: True, Angle: -19.81 degrees
# Is Open: True, Angle: -20.56 degrees
# Is Open: True, Angle: -21.21 degrees
# Is Open: True, Angle: -21.88 degrees
# Is Open: True, Angle: -22.71 degrees
# Is Open: True, Angle: -23.58 degrees
# Is Open: True, Angle: -25.07 degrees
# Is Open: True, Angle: -26.19 degrees
# Is Open: True, Angle: -26.95 degrees
# Is Open: True, Angle: -28.12 degrees
# Is Open: True, Angle: -28.72 degrees
# Is Open: True, Angle: -29.53 degrees
# Is Open: True, Angle: -30.19 degrees
# Is Open: True, Angle: -31.28 degrees
# Is Open: True, Angle: -32.65 degrees
# Is Open: True, Angle: -34.88 degrees
# Is Open: True, Angle: -37.45 degrees
# Is Open: True, Angle: -39.49 degrees
# Is Open: True, Angle: -41.51 degrees
# Is Open: True, Angle: -44.29 degrees
# Is Open: True, Angle: -46.78 degrees
# Is Open: True, Angle: -48.96 degrees
# Is Open: True, Angle: -52.73 degrees
# Is Open: True, Angle: -57.60 degrees
# Is Open: True, Angle: -66.97 degrees
# Is Open: True, Angle: -78.31 degrees
# Is Open: True, Angle: -88.60 degrees
# Is Open: True, Angle: -99.57 degrees
# Is Open: False, Angle: -109.04 degrees
# Is Open: False, Angle: -117.66 degrees
# Is Open: False, Angle: -123.50 degrees
# Is Open: False, Angle: -128.66 degrees
# Is Open: False, Angle: -127.95 degrees
# Is Open: False, Angle: -130.24 degrees
# Is Open: False, Angle: -130.68 degrees
# Is Open: False, Angle: -131.74 degrees
# Is Open: False, Angle: -133.49 degrees
# Is Open: False, Angle: -133.75 degrees
# Is Open: False, Angle: -133.49 degrees
# Is Open: False, Angle: -133.59 degrees
# Is Open: False, Angle: -134.36 degrees
# Is Open: False, Angle: -132.75 degrees
# Is Open: False, Angle: -131.89 degrees
# Is Open: False, Angle: -131.41 degrees
# Is Open: False, Angle: -131.40 degrees
# Is Open: False, Angle: -130.67 degrees
# Is Open: False, Angle: -130.40 degrees
# Is Open: False, Angle: -132.84 degrees
# Is Open: True, Angle: -133.00 degrees
# Is Open: False, Angle: -128.70 degrees
# Is Open: True, Angle: -129.04 degrees
# Is Open: True, Angle: -126.19 degrees
# Is Open: True, Angle: -124.04 degrees
# Is Open: True, Angle: -122.77 degrees
# Is Open: True, Angle: -120.50 degrees
# Is Open: True, Angle: -118.25 degrees
# Is Open: True, Angle: -115.80 degrees
# Is Open: True, Angle: -113.33 degrees
# Is Open: True, Angle: -110.92 degrees
# Is Open: True, Angle: -109.07 degrees
# Is Open: True, Angle: -107.39 degrees
# Is Open: True, Angle: -105.99 degrees
# Is Open: True, Angle: -105.73 degrees
# Is Open: True, Angle: -105.69 degrees
# Is Open: True, Angle: -105.28 degrees
# Is Open: True, Angle: -105.46 degrees
# Is Open: True, Angle: -106.06 degrees
# Is Open: True, Angle: -107.00 degrees
# Is Open: True, Angle: -107.47 degrees
# Is Open: True, Angle: -107.66 degrees
# Is Open: True, Angle: -107.75 degrees
# Is Open: True, Angle: -107.76 degrees
# Is Open: True, Angle: -107.60 degrees
# Is Open: False, Angle: -107.10 degrees
# Is Open: True, Angle: -106.62 degrees
# Is Open: True, Angle: -105.80 degrees
# Is Open: True, Angle: -104.73 degrees
# Is Open: True, Angle: -104.29 degrees
# Is Open: True, Angle: -103.59 degrees
# Is Open: True, Angle: -103.72 degrees
# Is Open: True, Angle: -103.72 degrees
# Is Open: True, Angle: -103.79 degrees
# Is Open: True, Angle: -104.59 degrees
# Is Open: True, Angle: -105.08 degrees
# Is Open: False, Angle: -105.56 degrees
# Is Open: False, Angle: -106.29 degrees
# Is Open: False, Angle: -106.50 degrees
# Is Open: False, Angle: -106.26 degrees
# Is Open: True, Angle: -105.03 degrees
# Is Open: True, Angle: -103.34 degrees
# Is Open: True, Angle: -100.59 degrees
# Is Open: True, Angle: -97.19 degrees
# Is Open: True, Angle: -94.61 degrees
# Is Open: True, Angle: -89.46 degrees
# Is Open: True, Angle: -84.23 degrees
# Is Open: True, Angle: -81.38 degrees
# Is Open: True, Angle: -76.70 degrees
# Is Open: True, Angle: -74.28 degrees
# Is Open: True, Angle: -71.40 degrees
# Is Open: True, Angle: -69.63 degrees
# Is Open: True, Angle: -68.00 degrees
# Is Open: True, Angle: -66.94 degrees
# Is Open: True, Angle: -65.85 degrees
# Is Open: True, Angle: -65.62 degrees
# Is Open: True, Angle: -65.03 degrees
# Is Open: True, Angle: -64.46 degrees
# Is Open: True, Angle: -64.11 degrees
# Is Open: True, Angle: -63.77 degrees
# Is Open: True, Angle: -62.75 degrees
# Is Open: True, Angle: -62.18 degrees
# Is Open: True, Angle: -61.39 degrees
# Is Open: True, Angle: -60.70 degrees
# Is Open: True, Angle: -60.48 degrees
# Is Open: True, Angle: -60.13 degrees
# Is Open: True, Angle: -59.78 degrees
# Is Open: True, Angle: -59.74 degrees
# Is Open: True, Angle: -58.99 degrees
# Is Open: True, Angle: -58.22 degrees
# Is Open: True, Angle: -56.61 degrees
# Is Open: True, Angle: -55.30 degrees
# Is Open: True, Angle: -53.30 degrees
# Is Open: True, Angle: -51.89 degrees
# Is Open: True, Angle: -50.92 degrees
# Is Open: True, Angle: -49.30 degrees
# Is Open: True, Angle: -46.78 degrees
# Is Open: True, Angle: -43.64 degrees
# Is Open: True, Angle: -39.98 degrees
# Is Open: True, Angle: -34.85 degrees
# Is Open: True, Angle: -28.55 degrees
# Is Open: True, Angle: -21.59 degrees
# Is Open: True, Angle: -13.15 degrees
# Is Open: True, Angle: -5.96 degrees
# Is Open: True, Angle: 3.49 degrees
# Is Open: True, Angle: 13.29 degrees
# Is Open: True, Angle: 20.61 degrees
# Is Open: True, Angle: 25.80 degrees
# Is Open: True, Angle: 31.04 degrees
# Is Open: True, Angle: 33.57 degrees
# Is Open: True, Angle: 36.35 degrees
# Is Open: True, Angle: 38.45 degrees
# Is Open: True, Angle: 39.63 degrees
# Is Open: True, Angle: 41.23 degrees
# Is Open: True, Angle: 41.56 degrees
# Is Open: True, Angle: 41.52 degrees
# Is Open: True, Angle: 41.19 degrees
# Is Open: True, Angle: 40.80 degrees
# Is Open: True, Angle: 40.45 degrees
# Is Open: True, Angle: 40.04 degrees
# Is Open: True, Angle: 40.65 degrees
# Is Open: True, Angle: 40.91 degrees
# Is Open: True, Angle: 42.93 degrees
# Is Open: True, Angle: 45.35 degrees
# Is Open: True, Angle: 47.52 degrees
# Is Open: True, Angle: 49.11 degrees
# Is Open: True, Angle: 52.03 degrees
# Is Open: True, Angle: 52.43 degrees
# Is Open: True, Angle: 52.51 degrees
# Is Open: True, Angle: 51.65 degrees
# Is Open: True, Angle: 52.00 degrees
# Is Open: True, Angle: 51.68 degrees
# Is Open: True, Angle: 51.23 degrees
# Is Open: True, Angle: 51.68 degrees
# Is Open: True, Angle: 52.99 degrees
# Is Open: True, Angle: 55.39 degrees
# Is Open: True, Angle: 58.06 degrees
# Is Open: True, Angle: 60.18 degrees
# Is Open: True, Angle: 64.20 degrees
# Is Open: True, Angle: 67.30 degrees
# Is Open: True, Angle: 69.68 degrees
# Is Open: True, Angle: 72.73 degrees
# Is Open: True, Angle: 75.56 degrees
# Is Open: True, Angle: 77.47 degrees
# Is Open: True, Angle: 78.91 degrees
# Is Open: True, Angle: 80.18 degrees
# Is Open: True, Angle: 81.01 degrees
# Is Open: True, Angle: 81.06 degrees
# Is Open: True, Angle: 80.24 degrees
# Is Open: True, Angle: 80.06 degrees
# Is Open: True, Angle: 80.23 degrees
# Is Open: True, Angle: 79.66 degrees
# Is Open: True, Angle: 79.31 degrees
# Is Open: True, Angle: 78.69 degrees
# Is Open: True, Angle: 78.05 degrees
# Is Open: True, Angle: 78.28 degrees
# Is Open: True, Angle: 78.69 degrees
# Is Open: True, Angle: 79.66 degrees
# Is Open: True, Angle: 81.25 degrees
# Is Open: True, Angle: 82.64 degrees
# Is Open: True, Angle: 85.91 degrees
# Is Open: True, Angle: 88.93 degrees
# Is Open: True, Angle: 92.41 degrees
# Is Open: True, Angle: 96.30 degrees
# Is Open: True, Angle: 100.70 degrees
# Is Open: True, Angle: 104.82 degrees
# Is Open: False, Angle: 110.49 degrees
# Is Open: False, Angle: 115.22 degrees
# Is Open: False, Angle: 121.76 degrees
# Is Open: False, Angle: 127.36 degrees
# Is Open: False, Angle: 132.27 degrees
# Is Open: False, Angle: 138.19 degrees
